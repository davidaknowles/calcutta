# %%
from pathlib import Path
import os
import sys

REPO_ROOT = next(path for path in [Path.cwd(), *Path.cwd().parents] if (path / "tealeaf").is_dir())
if str(REPO_ROOT) not in sys.path:
    sys.path.insert(0, str(REPO_ROOT))
os.chdir(REPO_ROOT)

# %%
import pandas as pd
import collections

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import TSNE # umap doesn't load :(

import time
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt

from tealeaf import calcutta
import scipy.sparse as sp
import scipy.io
import re

from importlib import reload
reload(calcutta)
sparse_sum = calcutta.sparse_sum

import seaborn as sns
import plotnine as p9
p9.theme_set(p9.theme_bw)

# %%
import umap

# %% [markdown]
# ## Check coverage per cell
#
# This code should all also work when using t2t_dedup (i.e. isoform level counts).

# %%
data_dir = Path("/gpfs/commons/groups/knowles_lab/data/sc/splitpool/microglia_less_mice")
#salmon_dir = data_dir / "salmon_spliceu" / "out_permit_known" / "quant_t2t_dedup" 
salmon_dir = data_dir / "salmon_per_sublib"# / "out_permit_known" / "quant_spliceu_t2g"

cells_meta = {}

srrdirs = [ item for item in salmon_dir.iterdir() if item.is_dir() ]
for srrdir in srrdirs: 
    cells_meta[srrdir.name] = pd.read_csv(srrdir / "out_permit_known" / "quant_spliceu_t2g" / "featureDump.txt", sep = "\t")
    cells_meta[srrdir.name]["sublibrary"] = srrdir.name
    
cells_meta = pd.concat(cells_meta.values(), axis=0)
#cells_meta = pd.read_csv(salmon_dir / "featureDump.txt", sep = "\t")
#cells_meta.shape # 192k cells in OG split-seq, 79k in microglia_less (30k according to paper, but these might be "half cells")
# 744k when using known BCs (!) for microglialess

# %%
plt.hist(np.log10(cells_meta.DeduplicatedReads), 100)
plt.xlabel("log10(deduped reads)")
# Out:
# Text(0.5, 0, 'log10(deduped reads)')

# %% [markdown]
# I think just the fat right tail are the real cells.

# %%
# get the Parse/V2 barcodes (thanks Scott!) 
parse_meta_dir = Path("/gpfs/commons/groups/knowles_lab/data/sc/splitpool/Parse_meta")
ligation_BCs_v2 = pd.read_csv(parse_meta_dir / "Parse_ligation_barcodes.txt", sep = "\t", header = None)
ligation_BCs_v2 = ligation_BCs_v2[0].tolist() 
ligation_BCs_v2[:5]
# Out:
# ['AACGTGAT', 'AAACATCG', 'ATGCCTAA', 'AGTGGTCA', 'ACCACTGT']

# %%
rt_BCs_v2 = pd.read_csv(parse_meta_dir / "Parse_RT_barcodes.txt", sep = "\t", header = None)
rt_BCs_v2 = rt_BCs_v2[0].tolist() 
len(rt_BCs_v2) # 96 barcodes (the order matters!)
# Out:
# 96

# %%
# read the counts matrix. cache in a binary format for faster loading. this take a while the first time. 
count_mat = {}
for srrdir in srrdirs: 
    print(srrdir)
    dat_dir = srrdir / "out_permit_known" / "quant_spliceu_t2g" / "alevin"
    cache_file = dat_dir / "quants_mat.npz"
    if cache_file.exists(): 
        count_mat[srrdir.name] = scipy.sparse.load_npz(cache_file)
    else: 
        count_mat[srrdir.name] = scipy.io.mmread(dat_dir / "quants_mat.mtx") # cells x genes
        scipy.sparse.save_npz(cache_file, count_mat[srrdir.name])
# Out:
# /gpfs/commons/groups/knowles_lab/data/sc/splitpool/microglia_less_mice/salmon_per_sublib/CAGATC
# /gpfs/commons/groups/knowles_lab/data/sc/splitpool/microglia_less_mice/salmon_per_sublib/ACTTGA
# /gpfs/commons/groups/knowles_lab/data/sc/splitpool/microglia_less_mice/salmon_per_sublib/CTTGTA
# /gpfs/commons/groups/knowles_lab/data/sc/splitpool/microglia_less_mice/salmon_per_sublib/TAGCTT
# /gpfs/commons/groups/knowles_lab/data/sc/splitpool/microglia_less_mice/salmon_per_sublib/GATCAG
# /gpfs/commons/groups/knowles_lab/data/sc/splitpool/microglia_less_mice/salmon_per_sublib/AGTCAA
# /gpfs/commons/groups/knowles_lab/data/sc/splitpool/microglia_less_mice/salmon_per_sublib/merge
# /gpfs/commons/groups/knowles_lab/data/sc/splitpool/microglia_less_mice/salmon_per_sublib/GGCTAC
# /gpfs/commons/groups/knowles_lab/data/sc/splitpool/microglia_less_mice/salmon_per_sublib/AGTTCC

# %%
sublib_keys = list(count_mat.keys())
sublib_keys
# Out:
# ['CAGATC',
#  'ACTTGA',
#  'CTTGTA',
#  'TAGCTT',
#  'GATCAG',
#  'AGTCAA',
#  'merge',
#  'GGCTAC',
#  'AGTTCC']

# %%
count_mat_all = scipy.sparse.vstack([count_mat[g] for g in sublib_keys])

# %%
count_mat_all.shape
# Out:
# (2093478, 56953)

# %%
genes = [ g.strip() for g in open(dat_dir / "quants_mat_cols.txt","r").readlines() ]
genes[:5] # these are transcripts if using t2t
# Out:
# ['ENSMUSG00000026315.14',
#  'ENSMUSG00000063558.5',
#  'ENSMUSG00000001138.14',
#  'ENSMUSG00000003135.16',
#  'ENSMUSG00000004709.15']

# %%
sublib_keys
# Out:
# ['CAGATC',
#  'ACTTGA',
#  'CTTGTA',
#  'TAGCTT',
#  'GATCAG',
#  'AGTCAA',
#  'merge',
#  'GGCTAC',
#  'AGTTCC']

# %%
cells_meta.sublibrary.drop_duplicates() == sublib_keys # all true
# Out:
# 0    True
# 0    True
# 0    True
# 0    True
# 0    True
# 0    True
# 0    True
# 0    True
# 0    True
# Name: sublibrary, dtype: bool

# %%
# used to keep track of what the corresponding row in the count matrix is
cells_meta = cells_meta.reset_index(drop=True).reset_index(names = "og_index")

# %%
# it was just a guess that this ordering is correct but it seems to be
polydT_hex_pairs_v2 = pd.DataFrame({"rnd1_BC" : rt_BCs_v2, "rnd1_well" : np.tile(np.arange(48), 2), "polydT" : [True] * 48 + [False] * 48}) 
ligation_BC_v2_dict = dict(zip(ligation_BCs_v2, np.arange(96)))

# %%
# extract the individual parts of the cell barcode
cells_meta["rnd3_BC"] = cells_meta.CB.str[:8]
cells_meta["rnd2_BC"] = cells_meta.CB.str[8:16]
cells_meta["rnd1_BC"] = cells_meta.CB.str[16:]

# convert to well IDs
cells_meta["rnd2_well"] = cells_meta["rnd2_BC"].map(ligation_BC_v2_dict)
cells_meta["rnd3_well"] = cells_meta["rnd3_BC"].map(ligation_BC_v2_dict)

cells_meta = pd.merge(cells_meta, polydT_hex_pairs_v2, on = "rnd1_BC")

# %%
# build the mapping between the polydT and ranhex "half" cells
cells_meta_select = cells_meta[ ['og_index', 'CB', 'rnd3_well', 'rnd2_well', 'rnd1_well', 'sublibrary'] ]
polydT_halfcells = cells_meta_select[cells_meta.polydT]
ranhex_halfcells = cells_meta_select[~cells_meta.polydT]
polydT_ranhex_map = pd.merge(
    polydT_halfcells, 
    ranhex_halfcells, 
    on = ['rnd3_well', 'rnd2_well', 'rnd1_well', 'sublibrary'], 
    how = 'inner', 
    suffixes = ["_polydT","_ranhex"])
polydT_ranhex_map.head()
# Out:
#    og_index_polydT                 CB_polydT  rnd3_well  rnd2_well  rnd1_well  \
# 0                6  CAGATCTGCGACTGGACTATTTCA          6         40         45
# 1                8  CGGATTGCCCATCCTCTGCTTGGG         89         84         24
# 2               11  CTCAATGAATCATTCCTTGGGAGA         42         80         23
# 3               14  CTCAATGAGATAGACAGTCGCGCG         42         48         43
# 4               18  GGTGCGAAAGCCATGCGACCTTTC         54         77         38
#
#   sublibrary  og_index_ranhex                 CB_ranhex
# 0     CAGATC             1012  CAGATCTGCGACTGGAATCTATAA
# 1     CAGATC              560  CGGATTGCCCATCCTCGCACTGAC
# 2     CAGATC               95  CTCAATGAATCATTCCGAGGTTGA
# 3     CAGATC              206  CTCAATGAGATAGACAGACAAAGC
# 4     CAGATC                5  GGTGCGAAAGCCATGCGTCCGTAG

# %% [markdown]
# ## Compare polydT and ranhex

# %%
len(ranhex_halfcells) # 483k
# Out:
# 813219

# %%
len(polydT_halfcells) # 865k lot more cells with polydT, why?
# Out:
# 1280259

# %%
ranhex_counts = count_mat_all.tocsr()[ranhex_halfcells.index,:]
ranhex_gene_sum = sparse_sum(ranhex_counts, 0)
ranhex_cell_sum = sparse_sum(ranhex_counts, 1)

# %%
polydT_counts = count_mat_all.tocsr()[polydT_halfcells.index,:]
polydT_gene_sum = sparse_sum(polydT_counts, 0)
polydT_cell_sum = sparse_sum(polydT_counts, 1)

# %%
# randex has more genes with 0 counts (expected?) 
plt.hist(np.log10(ranhex_gene_sum + 0.1), 30, alpha=0.3, label = "ranhex")
plt.hist(np.log10(polydT_gene_sum + 0.1), 30, alpha=0.3, label = "polydT")
plt.xlabel("log10(gene total count)")
plt.legend()
plt.show()

# %%
# cell counts overall pretty similar
plt.hist(np.log10(ranhex_cell_sum), 30, density=True, alpha=0.3, label = "ranhex")
plt.hist(np.log10(polydT_cell_sum), 30, density=True, alpha=0.3, label = "polydT")
plt.xlabel("log10(cell total count)")
plt.legend()

# %%
gene_sum = sparse_sum(count_mat_all, 0)
cell_sum = sparse_sum(count_mat_all, 1)

# %%
cells_to_keep = np.logical_and(cell_sum > 1000, cell_sum < 1e5) 
genes_to_keep = gene_sum > 10000 # pretty strict
genes_to_keep.sum()
# Out:
# 13120

# %%
count_sub = count_mat_all.tocsr()[cells_to_keep,:]

# %%
count_sub = count_sub[:,genes_to_keep]

# %%
count_sub.shape
# Out:
# (338977, 13120)

# %%
meta_sub = cells_meta[cells_to_keep]
meta_sub
# Out:
#          og_index                        CB  CorrectedReads  MappedReads  \
# 0               0  CCGACAACAACGTGATCGTGGTTG          294152       239450
# 1               1  CCGACAACTGGTGGTAATCTATAA          274205       234592
# 2               2  AACCGAGAATTGAGGATATCCGGG          269963       233274
# 3               3  AGCAGGAAGTCGTAGATATCCGGG          281046       238408
# 4               4  ATGCCTAACTAAGGTCATATTGGC          273913       237867
# ...           ...                       ...             ...          ...
# 1929452   1929452  AAGGTACAATCCTGTAGAGGTTGA            1888         1687
# 1929454   1929454  CGCTGATCCAATGGAACGTGGTTG            2053         1712
# 1929472   1929472  GAATCTGACACCTTACTCACTTTA            2045         1757
# 1929561   1929561  CAAGACTAAGATCGCAGAGGTTGA            2015         1777
# 1929651   1929651  CCGTGAGAATCATTCCGGGCGATG            2133         1748
#
#          DeduplicatedReads  MappingRate  DedupRate  MeanByMax  \
# 0              92185.58000     0.814035   0.384989   0.000698
# 1              89196.56000     0.855535   0.380220   0.001001
# 2              85309.67000     0.864096   0.365706   0.000418
# 3              93131.59000     0.848288   0.390640   0.000376
# 4              91409.51000     0.868403   0.384288   0.002002
# ...                    ...          ...        ...        ...
# 1929452         1286.99960     0.893538   0.762892   0.025943
# 1929454         1003.99300     0.833902   0.586445   0.020141
# 1929472         1015.99970     0.859169   0.578258   0.043624
# 1929561         1009.99963     0.881886   0.568373   0.080159
# 1929651         1010.99980     0.819503   0.578375   0.013615
#
#          NumGenesExpressed  NumGenesOverMean sublibrary   rnd3_BC   rnd2_BC  \
# 0                     8231               973     CAGATC  CCGACAAC  AACGTGAT
# 1                     9380              1477     CAGATC  CCGACAAC  TGGTGGTA
# 2                     8877              1222     CAGATC  AACCGAGA  ATTGAGGA
# 3                     8320               904     CAGATC  AGCAGGAA  GTCGTAGA
# 4                     9718              1767     CAGATC  ATGCCTAA  CTAAGGTC
# ...                    ...               ...        ...       ...       ...
# 1929452                954               169     AGTTCC  AAGGTACA  ATCCTGTA
# 1929454                744               128     AGTTCC  CGCTGATC  CAATGGAA
# 1929472                685               146     AGTTCC  GAATCTGA  CACCTTAC
# 1929561                700               158     AGTTCC  CAAGACTA  AGATCGCA
# 1929651                663               127     AGTTCC  CCGTGAGA  ATCATTCC
#
#           rnd1_BC  rnd2_well  rnd3_well  rnd1_well  polydT
# 0        CGTGGTTG          0         85         42   False
# 1        ATCTATAA         66         85         45   False
# 2        TATCCGGG         28         13         40   False
# 3        TATCCGGG         56         25         40   False
# 4        ATATTGGC         90          2         13   False
# ...           ...        ...        ...        ...     ...
# 1929452  GAGGTTGA         27         16         23   False
# 1929454  CGTGGTTG         31          8         42   False
# 1929472  TCACTTTA         83         45         47    True
# 1929561  GAGGTTGA         24         46         23   False
# 1929651  GGGCGATG         80         37         44   False
#
# [338977 rows x 18 columns]

# %%
rat = sp.diags(10000./ cell_sum[cells_to_keep]) @ count_sub

# %%
ge = np.log10(rat.toarray() + 1.)

# %%
scaler = StandardScaler()
data_standardized = scaler.fit_transform(ge)

pca = PCA(n_components=30)
low_rank_data = pca.fit_transform(data_standardized)

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x=low_rank_data[:,0], y=low_rank_data[:,1], hue = meta_sub["polydT"], linewidth=0, alpha = 0.1)
# Out:
# <Axes: >

# %%
umap_model = umap.UMAP() # (n_neighbors=5, min_dist=0.3, random_state=42)
embedding = umap_model.fit_transform(low_rank_data)
# Out:
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x=embedding[:,0], y=embedding[:,1], hue = meta_sub["polydT"], linewidth=0, alpha = 0.1)
# Out:
# <Axes: >

# %% [markdown]
# ## Align with preprocessed data
#
# The paper provided preprocessed data which we align our analysis with here. Note in the preprocessed data the ranhex and polydT halfcells have already been already combined.

# %%
preproc_BCs_id = [ g.strip() for g in open(data_dir / "GSM5693472_barcodes.tsv","r").readlines() ]
preproc_BCs = [ g.split("_")[0] for g in preproc_BCs_id ]
preproc_BCs_id[:5] # these are [rnd3 BC][rnd2 BC]_[rnd1 well ID]_[sublib ID]
# Out:
# ['TTCACGCAACGCTCGA_7_1',
#  'AAGACGGAAACGCTTA_8_1',
#  'CCATCCTCACCTCCAA_30_1',
#  'CCTCTATCCGACTGGA_24_1',
#  'GCTAACGACAAGACTA_23_1']

# %%
RT_BC_index = [ int(g.split("_")[1]) for g in preproc_BCs_id ]
set(RT_BC_index) == set(range(48)) # 48 rnd1 wells
# Out:
# True

# %%
sublib_index = [ g.split("_")[2] for g in preproc_BCs_id ]
set(sublib_index)  # 8 sublibs
# Out:
# {'1', '2', '3', '4', '5', '6', '7', '8'}

# %%
preproc_cellmeta = pd.read_csv(data_dir / "GSM5693472_cell_metadata.txt.gz", sep = "\t")
preproc_cellmeta.head()
# Out:
#    nCount_RNA  nFeature_RNA sample  rnd1_well  rnd2_well  rnd3_well  \
# 0       19978          4489    E-7          7         20         67
# 1       19974          4923    F-7          8         14         15
# 2       19966          4589    C-6         30         19         84
# 3       19949          4476    F-2         24         40         87
# 4       19941          5197    F-5         23         46         51
#
#   sublibrary RNA.Nuclei.Group    Age Sex         Sac  Dissection.Batch  \
# 0     ACTTGA           Group1  5.115   M   8/19/2020                 2
# 1     ACTTGA           Group2  5.082   M   8/12/2020                 2
# 2     ACTTGA           Group4  5.049   M  11/14/2019                 1
# 3     ACTTGA           Group4  5.049   F   8/12/2020                 2
# 4     ACTTGA           Group3  5.148   M   7/23/2020                 2
#
#                     DX  RIN  percent.mt class  cluster_name   clusternum_anno  \
# 0         5xFIRE + PBS  8.8    0.020022    EX   EX cortical  8-EX cortical L5
# 1  5xFIRE + transplant  8.3    0.590768   INH  INH midbrain    0-INH midbrain
# 2                 FIRE  7.6    0.030051    EX   EX thalamus    16-EX thalamus
# 3  5xFIRE + transplant  8.7    0.060153    EX   EX cortical  8-EX cortical L5
# 4  5xFIRE + transplant  8.3    0.235695  VLMC          VLMC           27-VLMC
#
#   clusters_4conditions cellchat_clusters
# 0                  NaN       EX cortical
# 1                  NaN      INH midbrain
# 2       15-EX thalamus       EX thalamus
# 3                  NaN       EX cortical
# 4                  NaN              VLMC

# %%
preproc_cellmeta.rnd1_well.max() 
# only 48 entries (zero indexed!) compared to 96 for rnd2 and rnd3. So hex+polydT already combined.
# Out:
# 47

# %%
preproc_cellmeta["rnd3_BC"] = [ g[:8] for g in preproc_BCs ]
preproc_cellmeta["rnd2_BC"] = [ g[8:] for g in preproc_BCs ]
preproc_cellmeta["sublib_BC"] = [ g.split("_")[2] for g in preproc_BCs_id ]

# %%
tab_BC2 = preproc_cellmeta.groupby(["rnd2_BC","rnd2_well"]).size() # correct, and gives mapping
tab_BC2 = tab_BC2.reset_index()
tab_BC2 = tab_BC2.sort_values("rnd2_well")

# %%
tab_BC3 = preproc_cellmeta.groupby(["rnd3_BC","rnd3_well"]).size() # correct, and gives mapping (think ordering is what I have)
tab_BC3 = tab_BC3.reset_index()
tab_BC3 = tab_BC3.sort_values("rnd3_well")
tab_BC3.head()
# Out:
#      rnd3_BC  rnd3_well    0
# 4   AACGTGAT          0  537
# 0   AAACATCG          1  528
# 36  ATGCCTAA          2  542
# 32  AGTGGTCA          3  523
# 18  ACCACTGT          4  543

# %%
preproc_cellmeta.groupby(["rnd2_BC","rnd2_well"]).size()
# Out:
# rnd2_BC   rnd2_well
# AAACATCG  1            574
# AACAACCA  12           535
# AACCGAGA  13           520
# AACGCTTA  14           524
# AACGTGAT  0            541
#                       ...
# TGAAGAGA  63           497
# TGGAACAA  64           534
# TGGCTTCA  65           571
# TGGTGGTA  66           553
# TTCACGCA  67           554
# Length: 96, dtype: int64

# %%
preproc_cellmeta.groupby(["sublibrary","sublib_BC"]).size() # correct
# Out:
# sublibrary  sublib_BC
# ACTTGA      1            4570
# AGTCAA      2            8132
# AGTTCC      3            7749
# CAGATC      4            4777
# CTTGTA      5            7613
# GATCAG      6            4992
# GGCTAC      7            6702
# TAGCTT      8            6792
# dtype: int64

# %%
ligation_BCs_v2 = np.array(ligation_BCs_v2).astype(str)
rt_BCs_v2 = np.array(rt_BCs_v2).astype(str)

# build the full cell BCs (one for ranhex, one for polydT) for the preproc data
rnd3_rnd2 = np.char.add( 
    ligation_BCs_v2[ preproc_cellmeta.rnd3_well.to_numpy() ],
    ligation_BCs_v2[ preproc_cellmeta.rnd2_well.to_numpy() ] )

preproc_cellmeta["full_BC_polydT"] = np.char.add( rnd3_rnd2, rt_BCs_v2[ preproc_cellmeta.rnd1_well.to_numpy() ] )
preproc_cellmeta["full_BC_ranhex"] = np.char.add( rnd3_rnd2, rt_BCs_v2[48:][ preproc_cellmeta.rnd1_well.to_numpy() ] )

# %%
cells_meta
# Out:
#          og_index                        CB  CorrectedReads  MappedReads  \
# 0               0  CCGACAACAACGTGATCGTGGTTG          294152       239450
# 1               1  CCGACAACTGGTGGTAATCTATAA          274205       234592
# 2               2  AACCGAGAATTGAGGATATCCGGG          269963       233274
# 3               3  AGCAGGAAGTCGTAGATATCCGGG          281046       238408
# 4               4  ATGCCTAACTAAGGTCATATTGGC          273913       237867
# ...           ...                       ...             ...          ...
# 2093473   2093473  GACAGTGCAAGAGATCATCTATAA             122          108
# 2093474   2093474  ATCCTGTAGATGAATCTATAGTCG             129          109
# 2093475   2093475  ACACGACCAGCAGGAATTGTCTTA             125          104
# 2093476   2093476  AGATCGCACGACTGGAGTGGGTTC             123          108
# 2093477   2093477  AGGCTAACCTGTAGCCTGTCTGAA             117          106
#
#          DeduplicatedReads  MappingRate  DedupRate  MeanByMax  \
# 0             92185.580000     0.814035   0.384989   0.000698
# 1             89196.560000     0.855535   0.380220   0.001001
# 2             85309.670000     0.864096   0.365706   0.000418
# 3             93131.590000     0.848288   0.390640   0.000376
# 4             91409.510000     0.868403   0.384288   0.002002
# ...                    ...          ...        ...        ...
# 2093473          55.989635     0.885246   0.518423   0.166636
# 2093474          70.897720     0.844961   0.650438   0.203729
# 2093475          52.992195     0.832000   0.509540   0.189258
# 2093476          57.000000     0.878049   0.527778   0.431818
# 2093477          45.997940     0.905983   0.433943   0.289295
#
#          NumGenesExpressed  NumGenesOverMean sublibrary   rnd3_BC   rnd2_BC  \
# 0                     8231               973     CAGATC  CCGACAAC  AACGTGAT
# 1                     9380              1477     CAGATC  CCGACAAC  TGGTGGTA
# 2                     8877              1222     CAGATC  AACCGAGA  ATTGAGGA
# 3                     8320               904     CAGATC  AGCAGGAA  GTCGTAGA
# 4                     9718              1767     CAGATC  ATGCCTAA  CTAAGGTC
# ...                    ...               ...        ...       ...       ...
# 2093473                 56                43     AGTTCC  GACAGTGC  AAGAGATC
# 2093474                 87                54     AGTTCC  ATCCTGTA  GATGAATC
# 2093475                 70                44     AGTTCC  ACACGACC  AGCAGGAA
# 2093476                 66                50     AGTTCC  AGATCGCA  CGACTGGA
# 2093477                 53                37     AGTTCC  AGGCTAAC  CTGTAGCC
#
#           rnd1_BC  rnd2_well  rnd3_well  rnd1_well  polydT
# 0        CGTGGTTG          0         85         42   False
# 1        ATCTATAA         66         85         45   False
# 2        TATCCGGG         28         13         40   False
# 3        TATCCGGG         56         25         40   False
# 4        ATATTGGC         90          2         13   False
# ...           ...        ...        ...        ...     ...
# 2093473  ATCTATAA         69         92         45   False
# 2093474  TATAGTCG         94         27          8   False
# 2093475  TTGTCTTA         25         73         21    True
# 2093476  GTGGGTTC         40         24         37   False
# 2093477  TGTCTGAA         10         78         13    True
#
# [2093478 rows x 18 columns]

# %%
polydT_merge = pd.merge(cells_meta, preproc_cellmeta, left_on = ["sublibrary","CB"], right_on = ["sublibrary", "full_BC_polydT"], how = "inner")
ranhex_merge = pd.merge(cells_meta, preproc_cellmeta, left_on = ["sublibrary","CB"], right_on = ["sublibrary","full_BC_ranhex"], how = "inner")

# %%
cells_meta.rnd1_well.max()
# Out:
# 47

# %%
preproc_cellmeta
# Out:
#        nCount_RNA  nFeature_RNA sample  rnd1_well  rnd2_well  rnd3_well  \
# 0           19978          4489    E-7          7         20         67
# 1           19974          4923    F-7          8         14         15
# 2           19966          4589    C-6         30         19         84
# 3           19949          4476    F-2         24         40         87
# 4           19941          5197    F-5         23         46         51
# ...           ...           ...    ...        ...        ...        ...
# 51322        2003          1194    C-3         33         38         71
# 51323        2003           576    C-6         30         65         35
# 51324        2003          1199    E-3         44         11         58
# 51325        2002           966    A-2         11         13         32
# 51326        2001          1097    C-1         18         35         38
#
#       sublibrary RNA.Nuclei.Group    Age Sex  ... class  \
# 0         ACTTGA           Group1  5.115   M  ...    EX
# 1         ACTTGA           Group2  5.082   M  ...   INH
# 2         ACTTGA           Group4  5.049   M  ...    EX
# 3         ACTTGA           Group4  5.049   F  ...    EX
# 4         ACTTGA           Group3  5.148   M  ...  VLMC
# ...          ...              ...    ...  ..  ...   ...
# 51322     TAGCTT           Group5  5.169   F  ...    EX
# 51323     TAGCTT           Group4  5.049   M  ...    EX
# 51324     TAGCTT           Group6  5.049   F  ...    EX
# 51325     TAGCTT           Group2  5.169   F  ...    EX
# 51326     TAGCTT           Group3  5.077   F  ...    EX
#
#                 cluster_name          clusternum_anno  \
# 0                EX cortical         8-EX cortical L5
# 1               INH midbrain           0-INH midbrain
# 2                EX thalamus           16-EX thalamus
# 3                EX cortical         8-EX cortical L5
# 4                       VLMC                  27-VLMC
# ...                      ...                      ...
# 51322            EX cortical    28-EX cortical L2/3/4
# 51323  EX cerebellum granule  3-EX cerebellum granule
# 51324            EX cortical      30-EX cortical L5/6
# 51325  EX cerebellum granule  3-EX cerebellum granule
# 51326            EX cortical      13-EX cortical L2/3
#
#           clusters_4conditions      cellchat_clusters   rnd3_BC   rnd2_BC  \
# 0                          NaN            EX cortical  TTCACGCA  ACGCTCGA
# 1                          NaN           INH midbrain  AAGACGGA  AACGCTTA
# 2               15-EX thalamus            EX thalamus  CCATCCTC  ACCTCCAA
# 3                          NaN            EX cortical  CCTCTATC  CGACTGGA
# 4                          NaN                   VLMC  GCTAACGA  CAAGACTA
# ...                        ...                    ...       ...       ...
# 51322    23-EX cortical L2/3/4            EX cortical  AATCCGTC  CCTCCTGA
# 51323  6-EX cerebellum granule  EX cerebellum granule  CCAGTTCA  TGGCTTCA
# 51324                      NaN            EX cortical  GTGTTCTA  AGTACAAG
# 51325  6-EX cerebellum granule  EX cerebellum granule  CACTTCGA  AACCGAGA
# 51326       8-EX cortical L2/3            EX cortical  CCTCCTGA  CCAGTTCA
#
#       sublib_BC            full_BC_polydT            full_BC_ranhex
# 0             1  TTCACGCAACGCTCGAATAAGCTC  TTCACGCAACGCTCGAACCGTACG
# 1             1  AAGACGGAAACGCTTAATTCATGG  AAGACGGAAACGCTTATATAGTCG
# 2             1  CCATCCTCACCTCCAACTTTGGTC  CCATCCTCACCTCCAATAATACGC
# 3             1  CCTCTATCCGACTGGATGCTTGGG  CCTCTATCCGACTGGAGCACTGAC
# 4             1  GCTAACGACAAGACTATTGGGAGA  GCTAACGACAAGACTAGAGGTTGA
# ...         ...                       ...                       ...
# 51322         8  AATCCGTCCCTCCTGAAGCGAAAC  AATCCGTCCCTCCTGAGGTTCTTC
# 51323         8  CCAGTTCATGGCTTCACTTTGGTC  CCAGTTCATGGCTTCATAATACGC
# 51324         8  GTGTTCTAAGTACAAGGTTACGTA  GTGTTCTAAGTACAAGGGGCGATG
# 51325         8  CACTTCGAAACCGAGACCGTTCTA  CACTTCGAAACCGAGAGCTGCATG
# 51326         8  CCTCCTGACCAGTTCATTATTCTG  CCTCCTGACCAGTTCAGCTTATAG
#
# [51327 rows x 25 columns]

# %%
both_merge = pd.merge(cells_meta, preproc_cellmeta, on = ["sublibrary","rnd1_well","rnd2_well","rnd3_well"], how = "inner")

# %%
match_counts = count_mat_all.tocsr()[both_merge.og_index,:]

# %%
gene_sum = sparse_sum(match_counts, 0)
cell_sum = sparse_sum(match_counts, 1)

# %%
plt.hist(np.log10(gene_sum + 0.1), 30)
plt.xlabel("log10(gene total count)")
plt.show()

# %%
plt.hist(np.log10(cell_sum), 30) # there are a LOT of cells with ~900 reads. 
plt.xlabel("log10(cell total count)")
cell_sum.min()
# Out:
# 49.9928811

# %%
cells_to_keep = np.logical_and(cell_sum > 3000, cell_sum < 3e4) 
cells_to_keep.sum()
# Out:
# 46986

# %%
# a more sensible analysis would probably filter somewhat on total count and then further on variance, but this is simpler
genes_to_keep = gene_sum > 10000
genes_to_keep.sum()
# Out:
# 5226

# %%
type(genes)
# Out:
# list

# %%
genes_sub = np.array(genes)[genes_to_keep]
genes_sub
# Out:
# array(['ENSMUSG00000006304.15', 'ENSMUSG00000023150.15',
#        'ENSMUSG00000015222.19', ..., 'ENSMUSG00000097497.3',
#        'ENSMUSG00000096768.9', 'ENSMUSG00000068457.15'], dtype='<U21')

# %%
np.savetxt('for_andrew/genes_small.txt', genes_sub, fmt='%s')

# %%
cells_to_keep.sum()
# Out:
# 46986

# %%
count_sub = match_counts.tocsr()[cells_to_keep,:]
count_sub = count_sub[:,genes_to_keep]

# seurat default normalization (i believe)
rat = sp.diags(10000./ cell_sum[cells_to_keep]) @ count_sub 
ge = np.log10(rat.toarray() + 1.)

# %%
# center and scale
scaler = StandardScaler()
data_standardized = scaler.fit_transform(ge)

pca = PCA(n_components=30)
low_rank_data = pca.fit_transform(data_standardized)

# %%
meta_sub = both_merge[cells_to_keep]

# %%
meta_sub.columns
# Out:
# Index(['og_index', 'CB', 'CorrectedReads', 'MappedReads', 'DeduplicatedReads',
#        'MappingRate', 'DedupRate', 'MeanByMax', 'NumGenesExpressed',
#        'NumGenesOverMean', 'sublibrary', 'rnd3_BC_x', 'rnd2_BC_x', 'rnd1_BC',
#        'rnd2_well', 'rnd3_well', 'rnd1_well', 'polydT', 'nCount_RNA',
#        'nFeature_RNA', 'sample', 'RNA.Nuclei.Group', 'Age', 'Sex', 'Sac',
#        'Dissection.Batch', 'DX', 'RIN', 'percent.mt', 'class', 'cluster_name',
#        'clusternum_anno', 'clusters_4conditions', 'cellchat_clusters',
#        'rnd3_BC_y', 'rnd2_BC_y', 'sublib_BC', 'full_BC_polydT',
#        'full_BC_ranhex'],
#       dtype='object')

# %%
meta_sub.drop(columns = ['og_index', 'CB', 'CorrectedReads', 'MappedReads', 'DeduplicatedReads',
       'MappingRate', 'DedupRate', 'MeanByMax', 'NumGenesExpressed',
       'NumGenesOverMean', "rnd3_BC_x", "rnd2_BC_x", "rnd1_BC", "nCount_RNA", "nFeature_RNA", 'rnd3_BC_y', 'rnd2_BC_y', 'full_BC_polydT',
       'full_BC_ranhex', 'sublib_BC']).to_csv('for_andrew/cells_meta.tsv.gz', sep='\t', index=False)
scipy.sparse.save_npz("for_andrew/counts_big.npz", count_sub, compressed = True )

# %%
sns.scatterplot(x=low_rank_data[:,0], y=low_rank_data[:,1], hue = meta_sub.polydT, linewidth=0, alpha = 0.1)
plt.xlabel("PC1")
plt.ylabel("PC2")
# Out:
# Text(0, 0.5, 'PC2')

# %%
meta_sub
# Out:
#        og_index                        CB  CorrectedReads  MappedReads  \
# 0          1384  GGTGCGAAGCCACATATATCCGGG           63776        53358
# 1          1424  GTCGTAGAAGGCTAACGGGCGATG           83580        56399
# 2          1602  ACCACTGTTTCACGCAGTCGCGCG           58493        50249
# 3          1652  CATACCAATCCGTCTAGGGTAGCG           62710        47288
# 4          1707  CTAAGGTCAAGGTACATCGTTTCG           65058        48320
# ...         ...                       ...             ...          ...
# 94939   1918118  AACGCTTAGCCACATATCACTTTA            9233         7837
# 94940   1918119  CGGATTGCCCAGTTCAGCTCGCGG            9416         7861
# 94946   1918128  CGGATTGCACATTGGCCTTTGGTC            8964         7794
# 94947   1918129  TATCAGCAATCCTGTATACTCGAA            9402         7738
# 94953   1918136  CCAGTTCAGTACGCAAGAGCACAA            9899         7871
#
#        DeduplicatedReads  MappingRate  DedupRate  MeanByMax  \
# 0             21750.0200     0.836647   0.407624   0.000683
# 1             25221.0180     0.674791   0.447189   0.001105
# 2             18396.9860     0.859060   0.366116   0.000867
# 3             20499.0230     0.754074   0.433493   0.000930
# 4             19725.0120     0.742722   0.408216   0.001557
# ...                  ...          ...        ...        ...
# 94939          4026.9897     0.848803   0.513843   0.018818
# 94940          3982.9985     0.834856   0.506678   0.009130
# 94946          4002.9930     0.869478   0.513599   0.007134
# 94947          4077.9920     0.823016   0.527009   0.015243
# 94953          4055.9312     0.795131   0.515301   0.003343
#
#        NumGenesExpressed  NumGenesOverMean  ... class            cluster_name  \
# 0                   2553                62  ...    EX   EX cerebellum granule
# 1                   2407                49  ...    EX   EX cerebellum granule
# 2                   2057                41  ...    EX   EX cerebellum granule
# 3                   2601                61  ...    EX   EX cerebellum granule
# 4                   2500                63  ...   ASC       ASC Bergmann glia
# ...                  ...               ...  ...   ...                     ...
# 94939               2000               307  ...   INH            INH midbrain
# 94940               1905               300  ...    EX  EX hippocampus granule
# 94946               1846               290  ...    EX             EX cortical
# 94947               1982               314  ...    EX             EX cortical
# 94953               1887               272  ...    EX             EX cortical
#
#                  clusternum_anno        clusters_4conditions  \
# 0        3-EX cerebellum granule     6-EX cerebellum granule
# 1        3-EX cerebellum granule                         NaN
# 2        3-EX cerebellum granule     6-EX cerebellum granule
# 3        3-EX cerebellum granule     6-EX cerebellum granule
# 4           20-ASC Bergmann glia        18-ASC Bergmann glia
# ...                          ...                         ...
# 94939             0-INH midbrain  0-INH mesencephalic tectum
# 94940  12-EX hippocampus granule                         NaN
# 94946        22-EX cortical L5/6          8-EX cortical L2/3
# 94947         2-EX cortical L2/3          1-EX cortical L2/3
# 94953         6-EX cortical L5/6                         NaN
#
#             cellchat_clusters  rnd3_BC_y  rnd2_BC_y  sublib_BC  \
# 0       EX cerebellum granule   GGTGCGAA   GCCACATA          4
# 1       EX cerebellum granule   GTCGTAGA   AGGCTAAC          4
# 2       EX cerebellum granule   ACCACTGT   TTCACGCA          4
# 3       EX cerebellum granule   CATACCAA   TCCGTCTA          4
# 4                         ASC   CTAAGGTC   AAGGTACA          4
# ...                       ...        ...        ...        ...
# 94939            INH midbrain   AACGCTTA   GCCACATA          3
# 94940  EX hippocampus granule   CGGATTGC   CCAGTTCA          3
# 94946             EX cortical   CGGATTGC   ACATTGGC          3
# 94947             EX cortical   TATCAGCA   ATCCTGTA          3
# 94953             EX cortical   CCAGTTCA   GTACGCAA          3
#
#                  full_BC_polydT            full_BC_ranhex
# 0      GGTGCGAAGCCACATATACTCGAA  GGTGCGAAGCCACATATATCCGGG
# 1      GTCGTAGAAGGCTAACGTTACGTA  GTCGTAGAAGGCTAACGGGCGATG
# 2      ACCACTGTTTCACGCAGTCGCGCG  ACCACTGTTTCACGCAGACAAAGC
# 3      CATACCAATCCGTCTATTACCTCG  CATACCAATCCGTCTAGGGTAGCG
# 4      CTAAGGTCAAGGTACAAATTTCTC  CTAAGGTCAAGGTACATCGTTTCG
# ...                         ...                       ...
# 94939  AACGCTTAGCCACATATCACTTTA  AACGCTTAGCCACATACTGAAAGG
# 94940  CGGATTGCCCAGTTCAGCTCGCGG  CGGATTGCCCAGTTCATCTTAATC
# 94946  CGGATTGCACATTGGCCTTTGGTC  CGGATTGCACATTGGCTAATACGC
# 94947  TATCAGCAATCCTGTATACTCGAA  TATCAGCAATCCTGTATATCCGGG
# 94953  CCAGTTCAGTACGCAAGAGCACAA  CCAGTTCAGTACGCAACGTGGTTG
#
# [46986 rows x 39 columns]

# %%
plt.figure(figsize=(5, 4))
sns.scatterplot(x=low_rank_data[:,0], y=low_rank_data[:,1], hue = meta_sub["class"], linewidth=0, alpha = 0.1)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("PC1")
plt.ylabel("PC2")
# Out:
# Text(0, 0.5, 'PC2')

# %%
polydT_merge.shape # good number
# Out:
# (51327, 42)

# %%
ranhex_merge.shape
# Out:
# (51296, 42)

# %%
count_mat_all.shape
# Out:
# (2093478, 56953)

# %% [markdown]
# ## Combine ranhex and polydT counts

# %%
polydT_counts = count_mat_all.tocsr()[polydT_ranhex_map.og_index_polydT,:]
ranhex_counts = count_mat_all.tocsr()[polydT_ranhex_map.og_index_ranhex,:]
comb_counts = polydT_counts + ranhex_counts # maybe should normalize by gene length for ranhex? would be good to look at this

# %%
comb_counts.shape
# Out:
# (632371, 56953)

# %%
join_on = ["sublibrary","rnd1_well","rnd2_well","rnd3_well"]
comb_meta = pd.merge(polydT_ranhex_map, preproc_cellmeta[join_on + ["class", "cluster_name"]], on = join_on, how = "left")
comb_meta["class"].value_counts(dropna = False)
# Out:
# class
# NaN     581075
# EX       23917
# INH      14540
# ASC       4515
# ODC       3140
# END        927
# OPC        917
# PER        883
# VLMC       835
# IMM        679
# EPD        401
# OB         359
# OEC        183
# Name: count, dtype: int64

# %%
gene_sum = sparse_sum(comb_counts, 0)
cell_sum = sparse_sum(comb_counts, 1)

# %%
plt.hist(np.log10(gene_sum + 0.1), 30)
plt.xlabel("log10(gene total count)")
plt.show()

# %%
plt.hist(np.log10(cell_sum), 30) # there are a LOT of cells with ~900 reads. 
plt.xlabel("log10(cell total count)")
cell_sum.min()
# Out:
# 81.99608451499999

# %%
cells_to_keep = np.logical_and(cell_sum > 3000, cell_sum < 3e4) 
cells_to_keep.sum()
# Out:
# 112249

# %%
# a more sensible analysis would probably filter somewhat on total count and then further on variance
genes_to_keep = gene_sum > 1000
genes_to_keep.sum()
# Out:
# 21858

# %%
count_sub = comb_counts.tocsr()[cells_to_keep,:]
count_sub = count_sub[:,genes_to_keep]

# seurat default normalization (i believe)
rat = sp.diags(10000./ cell_sum[cells_to_keep]) @ count_sub 
ge = np.log10(rat.toarray() + 1.)

# %%
# center and scale
scaler = StandardScaler()
data_standardized = scaler.fit_transform(ge)

pca = PCA(n_components=30)
low_rank_data = pca.fit_transform(data_standardized)

# %%
sns.scatterplot(x=low_rank_data[:,0], y=low_rank_data[:,1], linewidth=0, alpha = 0.1)
plt.xlabel("PC1")
plt.ylabel("PC2")
# Out:
# Text(0, 0.5, 'PC2')

# %%
tsne = TSNE(n_components=2)
embedding = tsne.fit_transform(low_rank_data)

# %%
cells_meta_sub = comb_meta[cells_to_keep]

# %%
cells_meta_sub["cluster_name"].isna().mean() # 30% missing from preprocessed
# Out:
# 0.6421705315860274

# %%
un = cells_meta_sub["cluster_name"].isna()
plt.figure(figsize = (8,6))
plt.subplots_adjust(left=0.05, right=0.75)
sns.scatterplot(x=embedding[un,0], y=embedding[un,1], color = 'gray', linewidth=0, alpha = 0.1)
sns.scatterplot(x=embedding[:,0], y=embedding[:,1], hue = cells_meta_sub['cluster_name'], linewidth=0, alpha = 0.1)
plt.legend(bbox_to_anchor=(1, 1), loc='upper left')

# %%
# preproc_cellmeta[["class", "cluster_name", "clusternum_anno", "clusters_4conditions", "cellchat_clusters"]].drop_duplicates().to_csv("temp.csv")

# %%
embedding = umap_model.fit_transform(low_rank_data)

un = cells_meta_sub["cluster_name"].isna()
plt.figure(figsize = (8,6))
plt.subplots_adjust(left=0.05, right=0.75)
sns.scatterplot(x=embedding[un,0], y=embedding[un,1], color = 'gray', linewidth=0, alpha = 0.1)
sns.scatterplot(x=embedding[:,0], y=embedding[:,1], hue = cells_meta_sub['cluster_name'], linewidth=0, alpha = 0.1)
plt.legend(bbox_to_anchor=(1, 1), loc='upper left')
# Out:
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.

# %%
import scanpy as sc

# %%
genes_sub = np.array(genes)[genes_to_keep]
genes_sub
# Out:
# array(['ENSMUSG00000026315.14', 'ENSMUSG00000063558.5',
#        'ENSMUSG00000001138.14', ..., 'ENSMUSG00000100968.2',
#        'ENSMUSG00000099973.2', 'ENSMUSG00000121343.1'], dtype='<U21')

# %%
count_sub.shape
# Out:
# (112249, 21858)

# %%
adata = sc.AnnData(X = comb_counts, var = pd.DataFrame({"gene_id":np.array(genes)}), obs = comb_meta[["class", "cluster_name"]])
sc.pp.filter_cells(adata, min_counts = 3000)
sc.pp.filter_cells(adata, max_counts = 3e4)
sc.pp.filter_genes(adata, min_cells=5)
adata.shape
# Out:
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
# (112249, 43015)

# %%
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)

# %%
sc.pp.highly_variable_genes(adata)
adata.shape
# Out:
# (112249, 43015)

# %%
adata.var.highly_variable.sum()
# Out:
# 7244

# %%
adata = adata[:, adata.var.highly_variable]

# %%
mouse_genes = pd.read_csv("ensembl_mouse_genes.txt.gz", sep = "\t")
mouse_genes = mouse_genes[ ['Gene stable ID', 'Gene name'] ]
mouse_genes.columns = ["gene_stable_id", "gene"]
mouse_genes = mouse_genes.drop_duplicates()
mouse_genes
# Out:
#             gene_stable_id     gene
# 0       ENSMUSG00000064336    mt-Tf
# 3       ENSMUSG00000064337  mt-Rnr1
# 7       ENSMUSG00000064338    mt-Tv
# 10      ENSMUSG00000064339  mt-Rnr2
# 14      ENSMUSG00000064340   mt-Tl1
# ...                    ...      ...
# 297303  ENSMUSG00000068134   Zfp120
# 297311  ENSMUSG00000068130   Zfp442
# 297312  ENSMUSG00000074593   Spint5
# 297313  ENSMUSG00000078891  Gm11008
# 297314  ENSMUSG00000094786  Gm14403
#
# [57180 rows x 2 columns]

# %%
adata.var["gene_stable_id"] = adata.var.gene_id.str.replace(r'\.\d+', '', regex = True)

adata.var = pd.merge( adata.var, mouse_genes, on = "gene_stable_id", how = "left")

is_missing = adata.var["gene"].isna()
adata.var["gene"][is_missing] = adata.var["gene_stable_id"][is_missing]

adata.var.index = adata.var["gene"]
adata.var_names_make_unique()

adata.var
# Out:
# /scratch/ipykernel_2615702/1997481896.py:1: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
# /scratch/ipykernel_2615702/1997481896.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /scratch/ipykernel_2615702/1997481896.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                         gene_id  n_cells  highly_variable     means  \
# gene
# Aox1       ENSMUSG00000063558.5    10357             True  0.173118
# Twist2     ENSMUSG00000007805.5     5482             True  0.045206
# Rxrg      ENSMUSG00000015843.11     8979             True  0.101996
# Cd34      ENSMUSG00000016494.10     8004             True  0.062919
# Ivns1abp  ENSMUSG00000023150.15    31968             True  0.313964
# ...                         ...      ...              ...       ...
# Kdm5d     ENSMUSG00000056673.15    19341             True  0.193801
# Eif2s3y   ENSMUSG00000069049.12    19914             True  0.207260
# Erdr1y     ENSMUSG00000096768.9    65618             True  0.868590
# Uty       ENSMUSG00000068457.15    29590             True  0.347205
# Ddx3y     ENSMUSG00000069045.12    10057             True  0.093206
#
#           dispersions  dispersions_norm      gene_stable_id      gene
# gene
# Aox1         1.290418          2.045190  ENSMUSG00000063558      Aox1
# Twist2       0.432778          0.569678  ENSMUSG00000007805    Twist2
# Rxrg         0.778880          1.165124  ENSMUSG00000015843      Rxrg
# Cd34         0.487569          0.663942  ENSMUSG00000016494      Cd34
# Ivns1abp     0.573496          0.811773  ENSMUSG00000023150  Ivns1abp
# ...               ...               ...                 ...       ...
# Kdm5d        0.522314          0.723718  ENSMUSG00000056673     Kdm5d
# Eif2s3y      0.553946          0.778141  ENSMUSG00000069049   Eif2s3y
# Erdr1y       1.312679          0.829759  ENSMUSG00000096768    Erdr1y
# Uty          0.700618          1.030480  ENSMUSG00000068457       Uty
# Ddx3y        0.476202          0.644387  ENSMUSG00000069045     Ddx3y
#
# [7244 rows x 8 columns]

# %%
sc.tl.pca(adata, svd_solver='arpack')
sc.pl.pca_variance_ratio(adata, log=False, n_pcs=50)

# %%
sc.pp.neighbors(adata, n_neighbors=10, n_pcs=30)
sc.tl.umap(adata)
sc.tl.leiden(adata, resolution=0.5)
sc.pl.umap(adata, color=['leiden'], legend_fontsize=8, save='_leiden')
# Out:
# /scratch/ipykernel_2615702/2320068165.py:3: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
# WARNING: saving figure to file figures/umap_leiden.pdf

# %%
umap_res = pd.DataFrame(adata.obsm["X_umap"], columns = ["UMAP1", "UMAP2"])
umap_res["leiden"] = adata.obs.reset_index().leiden
umap_res
# Out:
#             UMAP1      UMAP2 leiden
# 0        8.947482   4.817066     20
# 1        8.571629  13.457054     19
# 2        6.276886  11.243490      2
# 3        7.659700  19.320293      3
# 4       15.844229   8.939395      5
# ...           ...        ...    ...
# 112244  12.673298   9.763883     11
# 112245  13.991452  -0.906613      0
# 112246  13.289928  -0.555422      0
# 112247  13.643942  -0.916746      0
# 112248   9.828545  10.745427      1
#
# [112249 rows x 3 columns]

# %%
temp = adata.obs[~adata.obs.cluster_name.isna()]
cont_table = pd.crosstab(temp['cluster_name'], temp['leiden'])

# %%
plt.figure(figsize=(20,8))
sns.heatmap(cont_table, annot=True, cmap='YlGnBu', fmt='d', cbar=True)
# Out:
# <Axes: xlabel='leiden', ylabel='cluster_name'>

# %%
sc.pl.umap(adata, color=['cluster_name'], legend_fontsize=8)

# %%
sc.pl.umap(adata, color=['leiden'], legend_fontsize=8)

# %%
sc.tl.rank_genes_groups(adata, 'leiden', method='wilcoxon')

# The head function returns the top n genes per cluster
markers = pd.DataFrame(adata.uns['rank_genes_groups']['names'])
# Out:
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:429: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:431: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:434: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:444: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:455: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:429: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:431: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:434: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:444: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:455: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:429: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:431: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:434: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:444: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:455: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:429: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:431: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:434: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:444: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:455: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:429: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:431: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:434: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:444: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:455: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:429: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:431: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:434: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:444: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:455: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:429: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:431: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:434: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:444: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:455: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:429: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:431: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:434: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:444: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:455: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:429: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:431: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:434: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:444: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:455: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:429: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:431: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:434: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:444: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:455: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:429: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:431: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:434: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:444: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:455: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:429: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:431: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:434: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:444: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:455: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:429: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:431: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:434: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:444: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:455: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:429: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:431: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:434: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:444: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# /nfs/sw/easybuild/software/Python/3.12.3-GCCcore-13.3.0/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:455: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`

# %%
# sc.pl.rank_genes_groups(adata)

# %%
marker_names = pd.DataFrame(adata.uns['rank_genes_groups']['names'])
marker_names
# Out:
#              0                   1         2       3        4        5  \
# 0      Mir6236               Tafa1     Usp29    Rarb   Slc1a2     Rgs6
# 1       Il31ra              Lingo2    Lhfpl3   Adcy5    Plpp3     Cux2
# 2        Map1a               Cdh12       Nhs    Rgs9   Atp1a2    Chrm3
# 3        Kif5a                Sgcz  Cacna2d2    Gng7   Slc1a3   Cacng3
# 4       Camk1d              Hs6st3      Dpp6    Gnal     Gpc5    Fstl4
# ...        ...                 ...       ...     ...      ...      ...
# 7239     Ptprg                Hexb     Dleu2  Zbtb16   Tmeff2    Ptprm
# 7240      Dpp6       9330185C12Rik      Nfib    Nfib    Frmd5     Kazn
# 7241  Mir100hg             Gm41804    Slc4a4  Slc1a2  Slc24a2  Pitpnc1
# 7242     Kcnd2  ENSMUSG00000118642      Zeb2   Mast4   Frmpd4  Galntl6
# 7243    Frmd4a              Il31ra    Slc1a2    Zeb2     Dpp6   Zbtb20
#
#             6        7       8        9  ...             24       25       26  \
# 0      Hs3st4    Cdh12    Plp1    Satb2  ...          Cped1    Pcbp3   Spag16
# 1       Grik3   Pdzrn3     Mbp  Khdrbs3  ...           Eya2    Adcy8    Dnah6
# 2       Cdh18    Kcnh5    St18   Hs3st2  ...          Sned1     Msi2   Cfap44
# 3     Khdrbs3    Fhod3   Prr5l    Pde1a  ...  9530026P05Rik   Pcdh15    Spef2
# 4      Garnl3    Prr16    Mobp    Kcnt2  ...          Tmtc4    Hdac9  Shroom3
# ...       ...      ...     ...      ...  ...            ...      ...      ...
# 7239     Dpp6    Cplx2     Tnr    Luzp2  ...        Slc24a2    Pde8b   Tmeff2
# 7240   Hs6st3     Nfia  Pde10a   Igsf11  ...            Tnr    Cplx2     Dpp6
# 7241    Epha6      Qki   Kcnd2     Zeb1  ...          Nfasc    Xylt1    Gria1
# 7242   Zbtb20   Zbtb20  Frmd4a    Erbb4  ...          Kcnd2  Slc24a2    Kcnd2
# 7243  Kirrel3  Dscaml1   Gria1   Zbtb20  ...           Dpp6    Kcnq5   Frmd4a
#
#            27        28        29        30        31        32        33
# 0       Foxp2     Tshz2     Ntng2    Inpp5d     Sntb1      Nwd2     Astn2
# 1      Sox2ot     Vwc2l    Cadps2     Dock8     Sash1     Rbms3      Fat2
# 2       Robo1     Olfm3     Ptprt     Dock2     Plce1     Kctd8   Zfp385b
# 3       Kcnd2    Hs3st4     Nr4a2       Fyb  Mir100hg      Syt9      Chn2
# 4     Dlx6os1    Frmpd4  Tmem132d     Runx1       Ptn     Trpm3     Ndst3
# ...       ...       ...       ...       ...       ...       ...       ...
# 7239   Slc9a9     Fstl4     Trpm3    Tmeff2       Tnr  Cacna2d3    Camk1d
# 7240    Edil3     Alcam     Cntn5       Tnr    Pde10a     Pde4b     Mast4
# 7241     Nfia     Elmo1      Kazn    Pde10a     Nfasc     Unc5c      Sgcz
# 7242   Slc1a2     Plcl1     Epha6     Kcnd2      Dpp6      Etl4  Mir100hg
# 7243     Zeb2  Cacna2d3   Kirrel3  Mir100hg     Kcnd2     Ptprg     Gria1
#
# [7244 rows x 34 columns]

# %%
_ = plt.hist( np.array(pd.DataFrame(adata.uns['rank_genes_groups']['scores']) ).flatten(), 30)

# %%
known_markers = pd.read_csv("PanglaoDB_markers_27_Mar_2020.tsv.gz", sep = "\t")
known_markers.rename(columns={'official gene symbol': 'gene'}, inplace=True)
known_markers.head()
# Out:
#   species   gene     cell type           nicknames  ubiquitousness index  \
# 0   Mm Hs  CTRB1  Acinar cells                CTRB                 0.017
# 1   Mm Hs   KLK1  Acinar cells                Klk6                 0.013
# 2   Mm Hs  RBPJL  Acinar cells  RBP-L|SUHL|RBPSUHL                 0.001
# 3   Mm Hs  PTF1A  Acinar cells    PTF1-p48|bHLHa29                 0.001
# 4      Mm   TRY4  Acinar cells                 NaN                 0.007
#
#                                  product description            gene type  \
# 0                                chymotrypsinogen B1  protein-coding gene
# 1                                       kallikrein 1  protein-coding gene
# 2  recombination signal binding protein for immun...  protein-coding gene
# 3        pancreas associated transcription factor 1a  protein-coding gene
# 4                                          trypsin 4  protein coding gene
#
#    canonical marker germ layer     organ  sensitivity_human  \
# 0               1.0   Endoderm  Pancreas           1.000000
# 1               1.0   Endoderm  Pancreas           0.833333
# 2               1.0   Endoderm  Pancreas           0.000000
# 3               1.0   Endoderm  Pancreas           0.000000
# 4               1.0   Endoderm  Pancreas                NaN
#
#    sensitivity_mouse  specificity_human  specificity_mouse
# 0           0.957143           0.000629           0.015920
# 1           0.314286           0.005031           0.012826
# 2           0.000000           0.000000           0.000000
# 3           0.157143           0.000629           0.000773
# 4                NaN                NaN                NaN

# %%
known_markers["canonical marker"].value_counts(dropna=False)
# Out:
# canonical marker
# 1.0    5422
# NaN    2860
# 0.0       4
# Name: count, dtype: int64

# %%
mouse_markers = known_markers[known_markers.species.str.contains("Mm", na=False)]
mouse_markers = mouse_markers.rename(columns={"official gene symbol" : "gene"})

mouse_markers["cell type"].value_counts().head(5)
# Out:
# cell type
# Interneurons         220
# Neurons              211
# Endothelial cells    188
# Fibroblasts          177
# Germ cells           166
# Name: count, dtype: int64

# %%
mouse_markers["organ"].value_counts().head(5) # could limit to brain
# Out:
# organ
# Brain                1552
# Immune system        1516
# GI tract              511
# Kidney                441
# Connective tissue     398
# Name: count, dtype: int64

# %%
mouse_markers[mouse_markers["canonical marker"] == 1.]["organ"].value_counts().head(5) # lose about half the marker
# Out:
# organ
# Immune system    1204
# Brain             831
# GI tract          332
# Kidney            311
# Pancreas          308
# Name: count, dtype: int64

# %%
marker_scores = pd.DataFrame(adata.uns['rank_genes_groups']['scores'])

# %%
brain_markers = mouse_markers[ mouse_markers["organ"] == "Brain" ]
brain_markers.shape
# Out:
# (1552, 14)

# %%
brain_markers_filt = brain_markers[ (brain_markers.sensitivity_mouse>0.) & (brain_markers.specificity_mouse>0.) ]

# %%
p9.ggplot(brain_markers.fillna(0.), p9.aes(x="sensitivity_mouse", y="specificity_mouse", color = "cell type")) + p9.geom_point()

# %%
from collections import Counter
ct_counter = Counter() 
cell_type_anno = []
num_clusters = marker_names.shape[1]
for i in range(num_clusters):
    temp = pd.DataFrame({"gene":marker_names.iloc[:,i].str.upper(), "score":marker_scores.iloc[:,i]})
    temp = temp.merge(brain_markers_filt, on = "gene", how = "inner")
    res = temp.groupby('cell type').agg({'score': 'mean'}).sort_values(by='score', ascending=False)
    #print(res)
    ct = res.index[0]
    cell_type_anno.append(ct + ("" if (ct_counter[ct]==0) else "_%i"%(ct_counter[ct]+1)))
    ct_counter[ct] += 1

# %%
adata.obs.leiden = adata.obs.leiden.cat.rename_categories(cell_type_anno)

# %%
adata.obs.leiden
# Out:
# 720            Pyramidal cells_5
# 733            Pyramidal cells_4
# 734            GABAergic neurons
# 736            Pyramidal cells_2
# 745                      Neurons
#                    ...
# 618342    Retinal ganglion cells
# 618486           Pyramidal cells
# 628475           Pyramidal cells
# 628747           Pyramidal cells
# 628904          Immature neurons
# Name: leiden, Length: 112249, dtype: category
# Categories (34, object): ['Pyramidal cells', 'Immature neurons', 'GABAergic neurons', 'Pyramidal cells_2', ..., 'Microglia', 'Tanycytes', 'Pyramidal cells_7', 'Immature neurons_4']

# %%
mouse_markers
# Out:
#      species    gene                     cell type                  nicknames  \
# 0      Mm Hs   CTRB1                  Acinar cells                       CTRB
# 1      Mm Hs    KLK1                  Acinar cells                       Klk6
# 2      Mm Hs   RBPJL                  Acinar cells         RBP-L|SUHL|RBPSUHL
# 3      Mm Hs   PTF1A                  Acinar cells           PTF1-p48|bHLHa29
# 4         Mm    TRY4                  Acinar cells                        NaN
# ...      ...     ...                           ...                        ...
# 8281   Mm Hs   MYH11  Vascular smooth muscle cells                 SMMHC|SMHC
# 8282   Mm Hs  PDGFRB  Vascular smooth muscle cells  JTK12|CD140b|PDGFR1|PDGFR
# 8283   Mm Hs  SEMA3D  Vascular smooth muscle cells             coll-2|Sema-Z2
# 8284   Mm Hs   TBX18  Vascular smooth muscle cells                        NaN
# 8285   Mm Hs     WT1  Vascular smooth muscle cells       WIT-2|AWT1|NPHS4|GUD
#
#       ubiquitousness index                                product description  \
# 0                    0.017                                chymotrypsinogen B1
# 1                    0.013                                       kallikrein 1
# 2                    0.001  recombination signal binding protein for immun...
# 3                    0.001        pancreas associated transcription factor 1a
# 4                    0.007                                          trypsin 4
# ...                    ...                                                ...
# 8281                 0.015                              myosin heavy chain 11
# 8282                 0.033       platelet derived growth factor receptor beta
# 8283                 0.005                                      semaphorin 3D
# 8284                 0.004                                           T-box 18
# 8285                 0.010                                      Wilms tumor 1
#
#                 gene type  canonical marker germ layer          organ  \
# 0     protein-coding gene               1.0   Endoderm       Pancreas
# 1     protein-coding gene               1.0   Endoderm       Pancreas
# 2     protein-coding gene               1.0   Endoderm       Pancreas
# 3     protein-coding gene               1.0   Endoderm       Pancreas
# 4     protein coding gene               1.0   Endoderm       Pancreas
# ...                   ...               ...        ...            ...
# 8281  protein-coding gene               NaN   Mesoderm  Smooth muscle
# 8282  protein-coding gene               NaN   Mesoderm  Smooth muscle
# 8283  protein-coding gene               NaN   Mesoderm  Smooth muscle
# 8284  protein-coding gene               NaN   Mesoderm  Smooth muscle
# 8285  protein-coding gene               NaN   Mesoderm  Smooth muscle
#
#       sensitivity_human  sensitivity_mouse  specificity_human  \
# 0              1.000000           0.957143           0.000629
# 1              0.833333           0.314286           0.005031
# 2              0.000000           0.000000           0.000000
# 3              0.000000           0.157143           0.000629
# 4                   NaN                NaN                NaN
# ...                 ...                ...                ...
# 8281           0.000000           1.000000           0.016291
# 8282           0.000000           0.750000           0.036341
# 8283           0.000000           0.000000           0.001253
# 8284           0.000000           0.000000           0.000313
# 8285           0.000000           0.000000           0.022556
#
#       specificity_mouse
# 0              0.015920
# 1              0.012826
# 2              0.000000
# 3              0.000773
# 4                   NaN
# ...                 ...
# 8281           0.014697
# 8282           0.033246
# 8283           0.000000
# 8284           0.000000
# 8285           0.000000
#
# [7909 rows x 14 columns]
